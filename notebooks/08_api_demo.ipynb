# %% [markdown]
# # 08 — API demo
#
# Phase 5 checkpoint — test FridgeWise FastAPI endpoints.
#
# Start API first: `python scripts/run_api.py`

# %%
import httpx
BASE = "http://127.0.0.1:8000"
r = httpx.get(f"{BASE}/health", timeout=5)
print(r.json())

# %%
import json
r = httpx.post(f"{BASE}/recommend", json={"user_id": 5060, "k": 5}, timeout=60)
data = r.json()
print(json.dumps(data["recipes"][0], indent=2))

# %% [markdown]
# # 07 — Cold-start evaluation
#
# **Phase 4** — New user fallback, warm-up curve, substitutions, barcode example.
#
# Run: `python scripts/run_cold_start_eval.py`

# %%
from pathlib import Path
import sys
import json

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.evaluation.cold_start import run_cold_start_evaluation, save_warmup_chart

# %%
summary = run_cold_start_evaluation(ROOT)
print(json.dumps(summary["new_user_fallback"], indent=2))

# %%
import pandas as pd
from IPython.display import Image, display

display(pd.DataFrame(summary["warmup_curve"]))
chart = ROOT / "report" / "appendices" / "cold_start_warmup_curve.png"
save_warmup_chart(summary["warmup_curve"], chart)
display(Image(filename=str(chart)))

# %%
for ex in summary["substitution_examples"][:3]:
    print(ex["recipe_name"])
    for s in ex["substitutions"]:
        print(f"  {s['missing']} -> {s['substitute']} ({s['reason']})")

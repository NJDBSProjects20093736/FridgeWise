# %% [markdown]
# # 08b — Generative AI analysis (Phase 7)
#
# CA Part 3 — compare traditional vs generative approaches for ThriftyChef.
#
# See report §12 for full write-up.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

from src.genai.analysis import genai_comparison_table, recommend_genai_strategy, sample_llm_prompt
import pandas as pd

rows = [a.__dict__ for a in genai_comparison_table()]
pd.DataFrame(rows)

# %%
for k, v in recommend_genai_strategy().items():
    print(f"{k}: {v}")

# %%
print("Sample LLM prompt (optional Ollama layer):")
print(sample_llm_prompt("steak marinade", 0.6, ["garlic powder", "soy sauce"]))
